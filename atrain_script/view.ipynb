# %%
import os
import pathlib


meter_data = pathlib.Path(r'/data/xiu-hao/work/Dataset/MeterPaddle/train_data')

img0 = os.listdir(meter_data /  'rec' / 'train')[0]

# %%
import matplotlib.pyplot as plt

img0_path = meter_data /  'rec' / 'train' / img0
img0_array = plt.imread(img0_path)

plt.imshow(img0_array)

# %%
img0_array.shape
# Out:
# (32, 192, 3)
